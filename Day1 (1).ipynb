# %%
Str="Hello, World!"
print(Str[0:5])
# Out:
# Hello

# %%
string ="Python is fun"
print(string[7:9])
# Out:
# is

# %%
 my_string = "Programming"
 print(my_string[0::1])
# Out:
# Programming

# %%
my_string="abcdefgh"
print(my_string[0::2])
# Out:
# aceg

# %%
my_string="abcdefg"
print(my_string[-3::])
# Out:
# efg

# %%
string="Data Science"
print(string[-3::])
# Out:
# nce

# %%
Str= "abcdefghij"
print(Str[1::2])
# Out:
# bdfhj

# %%
string ="1234567890"
print(string[0::2])
# Out:
# 13579

# %%
string ="Hello"
print(string[::-1])
# Out:
# olleH

# %%
string ="abcdefghijk"
print(string[0::2])
# Out:
# acegik
