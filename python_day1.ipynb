# %% [markdown]
# <a href="https://colab.research.google.com/github/sreayarajan777/Python-Practice/blob/main/python_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'welcome to the python course 2025'
# Out:
# 'welcome to the python course 2025'

# %%
"hello"
# Out:
# 'hello'

# %%
23+3.1
# Out:
# 26.1

# %%
14+23
# Out:
# 37

# %%
print("hloo good morning\nwhere are you\n dont you want to learn english")
# Out:
# hloo good morning
# where are you
#  dont you want to learn english

# %%
print("five "+ "years old")
# Out:
# five years old

# %%
print("hello" +" " +input("whats your name?") +"!")
input("whats your name?")
# Out:
# hello angela!
# whats your name?hi
# 'hi'

# %%
input("whats your name")
# Out:
# whats your nameangella!
# 'angella!'

# %% [markdown]
# start class here 21/09/2025

# %%
print("SREAYA V.R","VAST","HELLO",890,sep="*")
print("VAST")
# Out:
# SREAYA V.R*VAST*HELLO*890
# VAST

# %%
name="sreaya"
age=22
education="MCA"
print(f"{name} is {age}years old.she is a {education}pg")
print({} is {})
# Out:
# sreaya is 22years old.she is a MCApg

# %%
snack="gulab jamun"
print(f"I love eating {snack} during meetings")
# Out:
# I love eating gulab jamun during meetings

# %%
print(type(snack))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
v

# %%
income=int(input("what is your income?"))
expenditure=int(input("what is your expense?"))
saving=income-expenditure
print(f"your saving is {saving}")
# Out:
# what is your income?38000
# what is your expense?30000
# your saving is 8000

# %%
avg1=20000
avg2=10000
Avg3=29000
avg4=21000
average=avg1+avg2+Avg3+avg4/4
print(f"your average is {average}")
# Out:
# your average is 64250.0

# %%
avg1=input((enter your income?))
avg2=input(enter your income)
average=int(avg1)+int(avg2)/4
print(average)
# Out:
#   File "/tmp/ipython-input-2456770818.py", line 1
#     avg1=input((enter your income?))
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
principle=float(input("enter principle amount"))
rate_of_interest=float(input("enter interest amount"))
years=float(input("enter interest amount"))
principle_interest=principle*rate_of_interest*years/100
amount=principle+principle_interest
print(amount)
# Out:
# enter principle amount5000
# enter interest amount10
# enter interest amount2
# 6000.0

# %%
name=input("whats your name")
l_name=input("whats")
print(name+l_name)
# Out:
# whats your namedeff
# whatsff
# deffff

# %%
str="i am learning python"
str[-5]
# Out:
# 'y'

# %%
str[0:3
]
# Out:
# 'i a'

# %%
str[-6:]
# Out:
# 'python'

# %%
email="sreayarAJANVELLAKKADA75@gmail.com       "
em=email.strip()
em=email.capitalize()
em=email.swapcase()
count.email
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4025308669.py in <cell line: 0>()
#       3 em=email.capitalize()
#       4 em=email.swapcase()
# ----> 5 print(count.email)
#
# NameError: name 'count' is not defined

# %%
str="my name is sreaya her name is maya our friend name is n2s"
str1=str
str1.count("name")
# Out:
# 3

# %%
str="my name is sreaya her name is maya our friend name is n2s"

str.count("name")
# Out:
# 3

# %%
str.replace("name","Name")
# Out:
# 'my Name is sreaya her Name is maya our friend Name is n2s'

# %%
str.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'sreaya',
#  'her',
#  'name',
#  'is',
#  'maya',
#  'our',
#  'friend',
#  'name',
#  'is',
#  'n2s']

# %%
type(str)
# Out:
# str

# %%
str2=str
str2.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'sreaya',
#  'her',
#  'name',
#  'is',
#  'maya',
#  'our',
#  'friend',
#  'name',
#  'is',
#  'n2s']

# %%
type(str2)
# Out:
# str

# %% [markdown]
# string practice

# %%
str="Once upon a time, in a magical forest, there lived a tiny fairy named Lily. She had sparkly wings and loved to fly at night. One evening, she saw a little star fall from the sky. "Oh no!" said Lily. "The star is lost!"

She flew through the trees, over flowers, and past sleepy owls to find it. At last, she saw the star sitting on a soft leaf, looking sad. "Don’t worry, little star," said Lily. "I’ll help you go home."

Lily gently picked up the star and flew up, up, up into the sky. With a sprinkle of fairy dust—poof!—the star twinkled and smiled. It was home again!"

# %%
print(len(str))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1857321960.py in <cell line: 0>()
# ----> 1 print(len(str))
#
# TypeError: object of type 'type' has no len()

# %%
story = "Once upon a time, in a magical forest, there lived a tiny fairy named Lily. She had sparkly wings and loved to fly at night. One evening, she saw a little star fall from the sky. 'Oh no!' said Lily. 'The star is lost!'

She flew through the trees, over flowers, and past sleepy owls to find it. At last, she saw the star sitting on a soft leaf, looking sad. 'Don’t worry, little star,' said Lily. 'I’ll help you go home.'

Lily gently picked up the star and flew up, up, up into the sky. With a sprinkle of fairy dust—poof!—the star twinkled and smiled. It was home again!"
print(len(story))
# Out:
#   File "/tmp/ipython-input-2135294610.py", line 1
#     story = "Once upon a time, in a magical forest, there lived a tiny fairy named Lily. She had sparkly wings and loved to fly at night. One evening, she saw a little star fall from the sky. 'Oh no!' said Lily. 'The star is lost!'
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str=" My name is  angela.i am 22 years old .she has 2 brothers and she is looking for a job.she have to finish the work before sunday "
print(len(str))
# Out:
# 129

# %%
str.split()
# Out:
# ['My',
#  'name',
#  'is',
#  'angela.i',
#  'am',
#  '22',
#  'years',
#  'old',
#  '.she',
#  'has',
#  '2',
#  'brothers',
#  'and',
#  'she',
#  'is',
#  'looking',
#  'for',
#  'a',
#  'job.she',
#  'have',
#  'to',
#  'finish',
#  'the',
#  'work',
#  'before',
#  'sunday']

# %%
str1="My name is  angela.i am 22 years old .she has 2 brothers and she is looking for a job.she have to finish the work before sunday "
print(str1.split())
print(type(str1))
# Out:
# ['My', 'name', 'is', 'angela.i', 'am', '22', 'years', 'old', '.she', 'has', '2', 'brothers', 'and', 'she', 'is', 'looking', 'for', 'a', 'job.she', 'have', 'to', 'finish', 'the', 'work', 'before', 'sunday']
# <class 'str'>

# %%
type(str1)
# Out:
# str

# %%
str[-6: :]
# Out:
# 'unday '

# %%
print("no of letters in your name" + len(input("enter your name")))
# Out:
# enter your namesreaya
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3819536318.py in <cell line: 0>()
# ----> 1 print("no of letters in your name" + len(input("enter your name")))
#
# TypeError: can only concatenate str (not "int") to str
